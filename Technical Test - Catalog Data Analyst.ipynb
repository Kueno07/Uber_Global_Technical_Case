# %% [markdown]
# Challenge: we need to build a logic to estimate all products that are duplicated, ie, they have different product_ids but they share the same content.

# %% [markdown]
# ### we don’t want the customer to see duplicated products.

# %% [markdown]
# The unique identifier for each product on Cornershop database is the **PRODUCT_ID** attribute.

# %% [markdown]
# # Script

# %% [markdown]
# ### Libraries and File upload

# %%
import pandas as pd
from pathlib import Path

# %%
home = str(Path.home())

# %%
path_read = home + '/Downloads/Base de Dados Python.csv'
df_database = pd.read_csv(path_read, dtype={'product_id': 'string',
                                            'product_name': 'string',
                                            'buy_unit': 'string',
                                            'package': 'string',
                                            'brand': 'string',
                                            'parent_category_id':'string',
                                            'category_id':'string',
                                            'parent_category_name': 'string',
                                            'category_name': 'string',
                                            'orders;;':'string'})

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Functions

# %%
def splitcom(value):
    value1 = value.split(',')
    return value1

def text_char(x):
    text_char =  unidecode.unidecode(str(x))
    return text_char

def order_clean(x):
    order_clean = str(x).replace(';','')
    return order_clean

def no_elements(list):
    count = 0
    for element in list:
        count += 1
    return count

# %% [markdown]
# # Data manipulation

# %%
df_database.head(3)
# Out:
#   product_id                product_name buy_unit          package  \
# 0          1             At√∫n en aceite       UN  3 u x 160 g c/u
# 1          2             At√∫n en aceite       UN           1730 g
# 2          3  At√∫n en aceite de girasol       UN  4 u x 160 g c/u
#
#         brand parent_category_id category_id   parent_category_name  \
# 0  Van Camp's                521          83  Productos en conserva
# 1  Van Camp's                521          83  Productos en conserva
# 2  Van Camp's                521          83  Productos en conserva
#
#                    category_name orders;;
# 0  Carnes y mariscos en conserva    262;;
# 1  Carnes y mariscos en conserva    387;;
# 2  Carnes y mariscos en conserva    600;;

# %%
df_len = df_database
df_len['len'] = df_len['product_id'].apply(lambda x: len(x))
df_len.rename(columns = {'orders;;': 'orders'}, inplace = True)

# Dataset ok
df_len_ok = df_len[(df_len['len']) <= 6 ]
df_len_ok = df_len_ok.drop(['len'],axis=1)

# Dataset nok
df_len_bad = df_len[(df_len['len']) > 7 ]
df_len_bad['split_list'] = df_len_bad['product_id'].apply(lambda x: splitcom(x))
df_len_bad['no_elements'] = df_len_bad['split_list'].apply(lambda x: no_elements(x))

# Dataset nok, 10 elements
df_len_bad_10 = df_len_bad[(df_len_bad['no_elements'] == 10)]
df_len_bad_10 = pd.DataFrame(df_len_bad_10['product_id'])
df_len_bad_10[['product_id_new', 'product_name','buy_unit', 'package', 'brand','parent_category_id', 'category_id','parent_category_name', 'category_name','orders']] = df_len_bad_10['product_id'].str.split(',', expand=True)
df_len_bad_10 = df_len_bad_10.drop(['product_id'],axis=1)
df_len_bad_10.rename(columns = {'product_id_new': 'product_id'}, inplace = True)
df_len_bad_10['product_name'] = df_len_bad_10['product_name'].apply(lambda x: x.replace('"',''))
df_len_bad_10['package'] = df_len_bad_10['package'].apply(lambda x: x.replace('"',''))
df_len_bad_10 = df_len_bad_10[pd.to_numeric(df_len_bad_10['product_id'], errors='coerce').notnull()]
df_len_bad_10 = df_len_bad_10[(df_len_bad_10['buy_unit'] == 'UN') | (df_len_bad_10['buy_unit'] == 'KG')]

# %% [markdown]
# ## Appending datasets

# %%
df_cleaned = df_len_ok.append(df_len_bad_10)

# Additional cleaning
df_cleaned['product_id'] = df_cleaned['product_id'].astype(int)
df_cleaned['parent_category_id'] = df_cleaned['parent_category_id'].astype(int)
df_cleaned['category_id'] = df_cleaned['category_id'].astype(int)
df_cleaned['orders'] = df_cleaned['orders'].apply(lambda x: order_clean(x))
df_cleaned['orders'] = df_cleaned['orders'].astype(int)
df_cleaned['package'] = df_cleaned['package'].fillna('-')
df_cleaned['brand'] = df_cleaned['brand'].fillna('-')
df_cleaned['product_name'] = df_cleaned['product_name'].apply(lambda x: x.lower())
df_cleaned['package'] = df_cleaned['package'].apply(lambda x: x.lower())
df_cleaned['brand'] = df_cleaned['brand'].apply(lambda x: x.lower())
df_cleaned['key'] = df_cleaned['product_name'] + "_" + df_cleaned['buy_unit'] + "_" + df_cleaned['package'] + "_" + df_cleaned['brand'] + "_" + df_cleaned['parent_category_id'].astype(str) + "_" + df_cleaned['category_id'].astype(str)
# Out:
# /var/folders/9k/2td9qcw563l80xbsy4yvr32c0000gn/T/ipykernel_43429/2549079233.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cleaned = df_len_ok.append(df_len_bad_10)

# %% [markdown]
# ## Removing duplicated products using key

# %%
# Summing up orders of duplicated products 
df_aux = df_cleaned.groupby(['key']).agg({'orders':'sum'}).reset_index()

# Replacing orders to sum of orders
df_cleaned_dup = df_cleaned
df_cleaned_dup.drop_duplicates(subset ='key', keep = 'first', inplace = True)
df_cleaned_dup = df_cleaned_dup.drop(['orders'],axis=1)
df_cleaned_dup = pd.merge(df_cleaned_dup, df_aux ,how="left", on=['key'])
df_cleaned_dup = df_cleaned_dup.drop(['key'],axis=1)

# %%
print('''
No. of rows in the raw dataset: {}
No. of rows in the cleaned dataset: {}
--------------------------------------------
Data loss: {:.2f}%
'''.format(df_database.shape[0], df_cleaned_dup.shape[0], ((df_cleaned_dup.shape[0]/df_database.shape[0])-1)*100))
# Out:
# No. of rows in the raw dataset: 128081
# No. of rows in the cleaned dataset: 106492
# --------------------------------------------
# Data loss: -16.86%

# %% [markdown]
# ## Getting a list of duplicated products

# %%
df_list_dup = df_database
df_list_dup['key'] = df_list_dup['product_name'] + "_" + df_list_dup['buy_unit'] + "_" + df_list_dup['package'] + "_" + df_list_dup['brand'] + "_" + df_list_dup['parent_category_id'].astype(str) + "_" + df_list_dup['category_id'].astype(str)

df_list_dup =  df_database.groupby(['key', 'brand']).agg({'product_id':'count'}).reset_index()
df_list_dup = df_list_dup[(df_list_dup['product_id']) > 1]
df_list_dup.sort_values(by=['product_id'],ascending=False, inplace=True)
list_dup = df_list_dup['key'].tolist()
df_list_dup_final = df_database[df_database['key'].isin(list_dup)]
df_list_dup_final.sort_values(by=['key','orders'],ascending=False, inplace=True)
df_list_dup_final = df_list_dup_final.drop(['len','key'],axis=1)
df_list_dup_final['orders'] = df_list_dup_final['orders'].apply(lambda x: order_clean(x))
df_list_dup_final['product_id'] = df_list_dup_final['product_id'].astype(int)
df_list_dup_final['parent_category_id'] = df_list_dup_final['parent_category_id'].astype(int)
df_list_dup_final['category_id'] = df_list_dup_final['category_id'].astype(int)
df_list_dup_final
# Out:
#        product_id          product_name buy_unit package        brand  \
# 65374       65372    Zuchinni org√°nico       UN   250 g  Hortifresco
# 65378       65376    Zuchinni org√°nico       UN   250 g  Hortifresco
# 48018       48016         Yogurt sligth       UN    200g      Colanta
# 48041       48039         Yogurt sligth       UN    200g      Colanta
# 48138       48136         Yogurt sligth       UN    200g      Colanta
# ...           ...                   ...      ...     ...          ...
# 90507       90505  Accesorios bisuteria       UN    2 un       Brilho
# 90508       90506  Accesorios bisuteria       UN    2 un       Brilho
# 90509       90507  Accesorios bisuteria       UN    2 un       Brilho
# 29035       29033     Abrelatas b√°sico       UN     1 u        Imusa
# 29302       29300     Abrelatas b√°sico       UN     1 u        Imusa
#
#        parent_category_id  category_id parent_category_name  \
# 65374                 538          136    Frutas y verduras
# 65378                 538          136    Frutas y verduras
# 48018                 512           24    L√°cteos y huevos
# 48041                 512           24    L√°cteos y huevos
# 48138                 512           24    L√°cteos y huevos
# ...                   ...          ...                  ...
# 90507                 560          638            Librer√≠a
# 90508                 560          638            Librer√≠a
# 90509                 560          638            Librer√≠a
# 29035                 551         1249      Ba√±os y cocina
# 29302                 551         1249      Ba√±os y cocina
#
#               category_name orders
# 65374      Verduras frescas    879
# 65378      Verduras frescas    279
# 48018               Yoghurt     94
# 48041               Yoghurt    907
# 48138               Yoghurt    608
# ...                     ...    ...
# 90507  Bisuter√≠a y cuentas    528
# 90508  Bisuter√≠a y cuentas    513
# 90509  Bisuter√≠a y cuentas    448
# 29035     Utensilios cocina    786
# 29302     Utensilios cocina     22
#
# [3370 rows x 10 columns]

# %% [markdown]
# ## Exporting file as xlsx

# %%
path_download = home + '/Downloads/DCA_test_Kokuda.xlsx'

with pd.ExcelWriter(path_download) as writer:
    df_cleaned_dup.to_excel(writer, sheet_name='dataset_cleaned',index=False)
    df_list_dup_final.to_excel(writer, sheet_name='list_of_duplications',index=False)

# %% [markdown]
# # This was used for discovery only

# %%
df_len_bad.groupby(['no_elements']).agg({'product_id':'count'}).reset_index()
# Out:
#     no_elements  product_id
# 0             1          15
# 1             2          17
# 2             4          12
# 3             5           1
# 4             7          10
# 5             9          16
# 6            10        1873
# 7            11       13861
# 8            12        3188
# 9            13         261
# 10           14          51
# 11           15           9
# 12           16           2

# %%
df_len_bad.head()
# Out:
#                                             product_id product_name buy_unit  \
# 15   16,At√∫n en aceite,UN,"6 un, 80 g c/u",Van Cam...         <NA>     <NA>
# 31   32,At√∫n vegetales,UN,"6 un, 150 g",Van Camp's...         <NA>     <NA>
# 33   34,Atun aceite,UN,"12 un, 80 g",Van Camp's,521...         <NA>     <NA>
# 88   89,Cerveza,UN,"24 un, 269 mL",Andina,515,40,Al...         <NA>     <NA>
# 101  102,Nestle Beso Negra 448g,UN,,Nestl√©,518,287...         <NA>     <NA>
#
#     package brand parent_category_id category_id parent_category_name  \
# 15     <NA>  <NA>               <NA>        <NA>                 <NA>
# 31     <NA>  <NA>               <NA>        <NA>                 <NA>
# 33     <NA>  <NA>               <NA>        <NA>                 <NA>
# 88     <NA>  <NA>               <NA>        <NA>                 <NA>
# 101    <NA>  <NA>               <NA>        <NA>                 <NA>
#
#     category_name orders  len  \
# 15           <NA>   <NA>  114
# 31           <NA>   <NA>  111
# 33           <NA>   <NA>  107
# 88           <NA>   <NA>   66
# 101          <NA>   <NA>   90
#
#                                             split_list  no_elements
# 15   [16, At√∫n en aceite, UN, "6 un,  80 g c/u", V...           11
# 31   [32, At√∫n vegetales, UN, "6 un,  150 g", Van ...           11
# 33   [34, Atun aceite, UN, "12 un,  80 g", Van Camp...           11
# 88   [89, Cerveza, UN, "24 un,  269 mL", Andina, 51...           11
# 101  [102, Nestle Beso Negra 448g, UN, , Nestl√©, 5...           11

# %%
x = df_len_bad[(df_len_bad['no_elements'] == 10)]
list_x = x['split_list'].tolist()[:5]
x = pd.DataFrame(list_x).T
x
# Out:
#                                          0  \
# 0                                      753
# 1  "Silla De Rueda Drive Pedi√°trica 14"""
# 2                                       UN
# 3
# 4                                    Drive
# 5                                      580
# 6                                      365
# 7                                    Salud
# 8         Equipos medici√≥n y dispositivos
# 9                                    198;;
#
#                                      1  \
# 0                                  770
# 1  "Silla de ruedas sport silver 18"""
# 2                                   UN
# 3                                1 und
# 4                                Drive
# 5                                  580
# 6                                  768
# 7                                Salud
# 8                            Ortopedia
# 9                                493;;
#
#                                             2  \
# 0                                         785
# 1  "Silla Ruedas Drive Transporte Acero 19"""
# 2                                          UN
# 3
# 4                                       Drive
# 5                                         580
# 6                                         365
# 7                                       Salud
# 8            Equipos medici√≥n y dispositivos
# 9                                       368;;
#
#                                         3                                 4
# 0                                    2412                              3552
# 1  Vaso de vidrio para licuadora \t4891-3  "Ventilador personal negro 13"""
# 2                                      UN                                UN
# 3                                   1 und                               2 u
# 4                                   Oster                           Cascade
# 5                                     554                               554
# 6                                     244                               241
# 7                            Electrohogar                      Electrohogar
# 8                      Electrodom√©sticos                      Ventilaci√≥n
# 9                                   208;;                             720;;

# %%
x = df_len_bad[(df_len_bad['no_elements'] == 11)]
list_x = x['split_list'].tolist()[:5]
x = pd.DataFrame(list_x).T
x
# Out:
#                                 0                              1  \
# 0                              16                             32
# 1                 At√∫n en aceite                At√∫n vegetales
# 2                              UN                             UN
# 3                           "6 un                          "6 un
# 4                       80 g c/u"                         150 g"
# 5                      Van Camp's                     Van Camp's
# 6                             521                            521
# 7                              83                             83
# 8           Productos en conserva          Productos en conserva
# 9   Carnes y mariscos en conserva  Carnes y mariscos en conserva
# 10                          750;;                          866;;
#
#                                 2         3                       4
# 0                              34        89                     102
# 1                     Atun aceite   Cerveza  Nestle Beso Negra 448g
# 2                              UN        UN                      UN
# 3                          "12 un    "24 un
# 4                           80 g"   269 mL"                 Nestl√©
# 5                      Van Camp's    Andina                     518
# 6                             521       515                     287
# 7                              83        40                 "Dulces
# 8           Productos en conserva   Alcohol      snacks y galletas"
# 9   Carnes y mariscos en conserva  Cervezas               Chocolate
# 10                          853;;     584;;                   727;;

# %%
x = df_len_bad[(df_len_bad['no_elements'] == 12)]
list_x = x['split_list'].tolist()[:5]
x = pd.DataFrame(list_x).T
x
# Out:
#                                               0                          1  \
# 0                                           131                        585
# 1   Galleta rellena con crema de coco cocosette        Almendras rebanadas
# 2                                            UN                         UN
# 3                                        "12 un                     21.3 g
# 4                                        480 g"                      Badia
# 5                                       Nestl√©                        518
# 6                                           518                       1004
# 7                                           981                    "Dulces
# 8                                       "Dulces         snacks y galletas"
# 9                            snacks y galletas"                    "Nueces
# 10                              Galletas dulces   semillas y frutas secas"
# 11                                        686;;                      273;;
#
#                              2                          3  \
# 0                          610                        612
# 1   "Saz√≥n Completa Bad√≠a 49          Semillas de ch√≠a
# 2                        6 gr"                         UN
# 3                           UN                     42.5 g
# 4                          "49                      Badia
# 5                         6gr"                        518
# 6                        Badia                       1004
# 7                          520                    "Dulces
# 8                           75         snacks y galletas"
# 9                     Despensa                    "Nueces
# 10      Especias y condimentos   semillas y frutas secas"
# 11                         1;;                      524;;
#
#                             4
# 0                         649
# 1           Aloe cristalizada
# 2                          UN
# 3                      28.3 g
# 4                       Badia
# 5                         518
# 6                        1004
# 7                     "Dulces
# 8          snacks y galletas"
# 9                     "Nueces
# 10   semillas y frutas secas"
# 11                      447;;

# %%
test_len_ok = df_len_ok
test_len_ok['key1'] = test_len_ok['product_name'] + "_" + test_len_ok['buy_unit'] + "_" + test_len_ok['package'] + "_" + test_len_ok['brand'] + "_" + test_len_ok['parent_category_id'].astype(str) + "_" + test_len_ok['category_id'].astype(str)
test_len_ok['key2'] = test_len_ok['buy_unit'] + "_" + test_len_ok['package'] + "_" + test_len_ok['brand'] + "_" + test_len_ok['parent_category_id'].astype(str) + "_" + test_len_ok['category_id'].astype(str)
test_len_ok
# Out:
#        product_id                        product_name buy_unit  \
# 0               1                     At√∫n en aceite       UN
# 1               2                     At√∫n en aceite       UN
# 2               3          At√∫n en aceite de girasol       UN
# 3               4                       At√∫n en agua       UN
# 4               5                       At√∫n en agua       UN
# ...           ...                                 ...      ...
# 128076     128034                       Cebolla larga       KG
# 128077     128035                            Cilantro       UN
# 128078     128036                   Frijol desgranado       KG
# 128079     128037                             Guascas       UN
# 128080     128038  Lechuga crespa hidrop√≥nica morada       UN
#
#                  package       brand parent_category_id category_id  \
# 0        3 u x 160 g c/u  Van Camp's              521.0        83.0
# 1                 1730 g  Van Camp's              521.0        83.0
# 2        4 u x 160 g c/u  Van Camp's              521.0        83.0
# 3        6 u x 160 g c/u  Van Camp's              521.0        83.0
# 4         3 u x 80 g c/u  Van Camp's              521.0        83.0
# ...                  ...         ...                ...         ...
# 128076          Por peso         NaN                538         136
# 128077  Paquete de 100 g         NaN                538         135
# 128078          Por peso         NaN                538         136
# 128079  Paquete de 100 g         NaN                538         135
# 128080           Paquete         NaN                538         136
#
#          parent_category_name                  category_name orders  \
# 0       Productos en conserva  Carnes y mariscos en conserva  262;;
# 1       Productos en conserva  Carnes y mariscos en conserva  387;;
# 2       Productos en conserva  Carnes y mariscos en conserva  600;;
# 3       Productos en conserva  Carnes y mariscos en conserva  749;;
# 4       Productos en conserva  Carnes y mariscos en conserva  259;;
# ...                       ...                            ...    ...
# 128076      Frutas y verduras               Verduras frescas  720;;
# 128077      Frutas y verduras                Hierbas frescas  199;;
# 128078      Frutas y verduras               Verduras frescas  973;;
# 128079      Frutas y verduras                Hierbas frescas   34;;
# 128080      Frutas y verduras               Verduras frescas  180;;
#
#                                                      key1  \
# 0       At√∫n en aceite_UN_3 u x 160 g c/u_Van Camp's_...
# 1         At√∫n en aceite_UN_1730 g_Van Camp's_521.0_83.0
# 2       At√∫n en aceite de girasol_UN_4 u x 160 g c/u_...
# 3       At√∫n en agua_UN_6 u x 160 g c/u_Van Camp's_52...
# 4       At√∫n en agua_UN_3 u x 80 g c/u_Van Camp's_521...
# ...                                                   ...
# 128076                                                NaN
# 128077                                                NaN
# 128078                                                NaN
# 128079                                                NaN
# 128080                                                NaN
#
#                                             key2
# 0       UN_3 u x 160 g c/u_Van Camp's_521.0_83.0
# 1                UN_1730 g_Van Camp's_521.0_83.0
# 2       UN_4 u x 160 g c/u_Van Camp's_521.0_83.0
# 3       UN_6 u x 160 g c/u_Van Camp's_521.0_83.0
# 4        UN_3 u x 80 g c/u_Van Camp's_521.0_83.0
# ...                                          ...
# 128076                                       NaN
# 128077                                       NaN
# 128078                                       NaN
# 128079                                       NaN
# 128080                                       NaN
#
# [108765 rows x 12 columns]

# %%
df_dsclean_dupcheck2 =  test_len_ok.groupby(['key2']).agg({'product_id':'count'}).reset_index()
df_dsclean_dupcheck2 = df_dsclean_dupcheck2[(df_dsclean_dupcheck2['product_id']) > 1]
df_dsclean_dupcheck2.sort_values(by=['product_id'],ascending=False, inplace=True)
df_dsclean_dupcheck2
# Out:
#                                    key2  product_id
# 35388       UN_Talla S_No-Varix_580_768         262
# 35413      UN_Talla XL_No-Varix_580_768         261
# 35345       UN_Talla M_No-Varix_580_768         258
# 35292       UN_Talla L_No-Varix_580_768         256
# 3877              UN_1.0_Bardot_527_974         185
# ...                                 ...         ...
# 15405          UN_3 und_Gum_527.0_967.0           2
# 15395  UN_3 und_Evergreen_1209.0_1228.0           2
# 15394       UN_3 und_Eterna_526.0_985.0           2
# 15392        UN_3 und_Durex_580.0_679.0           2
# 17055             UN_3050 ml_Pow_514_36           2
#
# [9525 rows x 2 columns]

# %%
df_dsclean_dupcheck1 =  test_len_ok.groupby(['key1', 'brand']).agg({'product_id':'count'}).reset_index()
df_dsclean_dupcheck1 = df_dsclean_dupcheck1[(df_dsclean_dupcheck1['product_id']) > 1]
df_dsclean_dupcheck1.sort_values(by=['product_id'],ascending=False, inplace=True)
df_dsclean_dupcheck1
# Out:
#                                                     key1        brand  \
# 61484  Vestido de fiesta mu√±ecas tipo american/our g...        Zassy
# 33487  Labial l√≠quido aca√≠ larga duraci√≥n_UN_6 ml_...        Vit√∫
# 61058                            Vaso_UN_1 u_Aro_553_249          Aro
# 12330  Camiseta infantil dra clown_UN_Unidad_Dra Clow...    Dra Clown
# 33296  Labial color sensational_UN_4.2 g_Maybelline_5...   Maybelline
# ...                                                  ...          ...
# 12003  Calcetin mujer transparente puntera abierta 15...     No-Varix
# 12002  Calcetin mujer transparente puntera abierta 15...     No-Varix
# 12001  Calcetin mujer transparente puntera abierta 15...     No-Varix
# 12000  Calcetin mujer transparente puntera abierta 15...     No-Varix
# 64447  Zuchinni org√°nico_UN_250 g_Hortifresco_538.0_...  Hortifresco
#
#        product_id
# 61484          10
# 33487           9
# 61058           9
# 12330           8
# 33296           8
# ...           ...
# 12003           2
# 12002           2
# 12001           2
# 12000           2
# 64447           2
#
# [1539 rows x 3 columns]
